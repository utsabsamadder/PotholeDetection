# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
import os
from IPython.display import Image, display
from IPython import display
display.clear_output()
# !yolo checks
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 30.2/78.2 GB disk)
#
# OS                  Linux-6.1.85+-x86_64-with-glibc2.35
# Environment         Colab
# Python              3.10.12
# Install             pip
# RAM                 12.67 GB
# CPU                 Intel Xeon 2.00GHz
# CUDA                12.1
#
# matplotlib          ✅ 3.7.1>=3.3.0
# opencv-python       ✅ 4.8.0.76>=4.6.0
# pillow              ✅ 9.4.0>=7.1.2
# pyyaml              ✅ 6.0.1>=5.3.1
# requests            ✅ 2.31.0>=2.23.0
# scipy               ✅ 1.11.4>=1.4.1
# torch               ✅ 2.3.0+cu121>=1.8.0
# torchvision         ✅ 0.18.0+cu121>=0.9.0
# tqdm                ✅ 4.66.4>=4.64.0
# psutil              ✅ 5.9.5
# py-cpuinfo          ✅ 9.0.0
# pandas              ✅ 2.0.3>=1.1.4
# seaborn             ✅ 0.13.1>=0.11.0
# ultralytics-thop    ✅ 0.2.7>=0.2.5

# %%
# !mkdir -p /content/Pothole/datasets
# %cd /content/Pothole/datasets
# Out:
# /content/Pothole/datasets

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3ZRKNCyLkGRv1ai9Kx3A")
project = rf.workspace("nit-raipur-nz8f9").project("pothole-detection-deployment")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.28, to fix: `pip install ultralytics==8.0.196`

# %%
# !yolo task=detect mode=train model=/content/yolov8s.pt data=/content/Pothole/datasets/Pothole-Detection-Deployment-2/data.yaml epochs=120 imgsz=640
# Out:
# Ultralytics YOLOv8.2.28 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# *Confustion Matrix*

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to the image file
image_path = '/content/Pothole/datasets/runs/detect/train2/confusion_matrix.png'

# Load and display the image
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers and ticks
plt.show()

# %% [markdown]
# *Result*

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to the image file
image_path = '/content/Pothole/datasets/runs/detect/train2/results.png'

# Load and display the image
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers and ticks
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to the image file
image_path = '/content/Pothole/datasets/runs/detect/train2/train_batch2.jpg'

# Load and display the image
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers and ticks
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to the image file
image_path = '/content/Pothole/datasets/runs/detect/train2/val_batch0_pred.jpg'

# Load and display the image
img = mpimg.imread(image_path)
plt.imshow(img)
plt.axis('off')  # Turn off axis numbers and ticks
plt.show()
